# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pk_df = pd.read_csv('/content/sample_data/Pokemon.csv',index_col=0)

# %%
pk_df.head() #Por defecto el método head me muestra los primeros 5 registros del dataframe
# Out:
#                        name  type1   type2  total  hp  attack  defense  \
# number
# 1                 Bulbasaur  Grass  Poison    318  45      49       49
# 2                   Ivysaur  Grass  Poison    405  60      62       63
# 3                  Venusaur  Grass  Poison    525  80      82       83
# 3             Mega Venusaur  Grass  Poison    625  80     100      123
# 3       Gigantamax Venusaur  Grass  Poison    525  80      82       83
#
#         sp_attack  sp_defense  speed  generation  legendary
# number
# 1              65          65     45           1      False
# 2              80          80     60           1      False
# 3             100         100     80           1      False
# 3             122         120     80           1      False
# 3             100         100     80           1      False

# %% [markdown]
# #### Problemas a atacar
# * Valores nulos
# * Error de ortografía VenusaurMega Venusaur	= Mega Venusaur
# * IDs duplicados

# %%
pk_df.head(10) #El método head como comenté previamente, me muestra los primeros 5 elementos pero sin argumento, si colocamos el número 10 me muestra los 10 argumentos que he mandado como parámetro
# Out:
#                        name  type1   type2  total  hp  attack  defense  \
# number
# 1                 Bulbasaur  Grass  Poison    318  45      49       49
# 2                   Ivysaur  Grass  Poison    405  60      62       63
# 3                  Venusaur  Grass  Poison    525  80      82       83
# 3             Mega Venusaur  Grass  Poison    625  80     100      123
# 3       Gigantamax Venusaur  Grass  Poison    525  80      82       83
# 4                Charmander   Fire     NaN    309  39      52       43
# 5                Charmeleon   Fire     NaN    405  58      64       58
# 6                 Charizard   Fire  Flying    534  78      84       78
# 6          Mega Charizard X   Fire  Dragon    634  78     130      111
# 6          Mega Charizard Y   Fire  Flying    634  78     104       78
#
#         sp_attack  sp_defense  speed  generation  legendary
# number
# 1              65          65     45           1      False
# ...

# %%
'''
Error de sintaxis
VenusaurMega Venusaur -> Mega Venusaur
'''
# Out:
# '\nError de sintaxis\nVenusaurMega Venusaur -> Mega Venusaur\n'

# %%
help(str.replace) # me devuelve una copia del elemento de, este pide diferentes parámetros, el valor por defecto y el valor que debo cambiar
# Out:
# Help on method_descriptor:
#
# replace(self, old, new, count=-1, /)
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %%
nuevo_reemplazo = pk_df.name.str.replace('.*(?=Mega)','Mega Venusaur') # De  la columna Name cualquier registro que tenga un escrito como .*(?=Mega) lo reemplace por "Mega Venasaur"

nuevo_reemplazo
# Out:
# number
# 1                 Bulbasaur
# 2                   Ivysaur
# 3                  Venusaur
# 3             Mega Venusaur
# 3       Gigantamax Venusaur
#                ...
# 896               Glastrier
# 897               Spectrier
# 898                 Calyrex
# 898       Ice Rider Calyrex
# 898    Shadow Rider Calyrex
# Name: name, Length: 1072, dtype: object

# %%
pk_df.head(10) #Muestreme los primeros 10 registros del dataframe
# Out:
#                        name  type1   type2  total  hp  attack  defense  \
# number
# 1                 Bulbasaur  Grass  Poison    318  45      49       49
# 2                   Ivysaur  Grass  Poison    405  60      62       63
# 3                  Venusaur  Grass  Poison    525  80      82       83
# 3             Mega Venusaur  Grass  Poison    625  80     100      123
# 3       Gigantamax Venusaur  Grass  Poison    525  80      82       83
# 4                Charmander   Fire     NaN    309  39      52       43
# 5                Charmeleon   Fire     NaN    405  58      64       58
# 6                 Charizard   Fire  Flying    534  78      84       78
# 6          Mega Charizard X   Fire  Dragon    634  78     130      111
# 6          Mega Charizard Y   Fire  Flying    634  78     104       78
#
#         sp_attack  sp_defense  speed  generation  legendary
# number
# 1              65          65     45           1      False
# ...

# %%
#pdf = pk_df.name.str.upper() #seleccione el dataframe y de la función propia de string en python reemplace el texto a minúscula
pk_df_columns = pk_df.name.str.lower() #seleccione el dataframe y de la función propia de string en python reemplace el texto a mayúscula

# %%
pdf
# Out:
# number
# 1                 BULBASAUR
# 2                   IVYSAUR
# 3                  VENUSAUR
# 3             MEGA VENUSAUR
# 3       GIGANTAMAX VENUSAUR
#                ...
# 896               GLASTRIER
# 897               SPECTRIER
# 898                 CALYREX
# 898       ICE RIDER CALYREX
# 898    SHADOW RIDER CALYREX
# Name: name, Length: 1072, dtype: object

# %%
"""
En esta línea de código me guarda en una variable el reemplazo de los registros del dataframe.
Vemos que hay comillas separadas por comas.
el primer parametro representa el valor que deseamos reemplazar
el segundo parámetro el que se va a reemplazar, en esta línea de código no hay ninguna columna llamada COLUMNS, por ende, no efectua ningún cambio
pero colums es una palabra reservada, que representa las columnas del dataframe
"""
pk_df.columns = pk_df.columns.str.replace('','')

# %%
pk_df.columns # Me devuelve el index del dtaframe, que son las columnas representativas del dataframe.
# Out:
# Index(['name', 'type1', 'type2', 'total', 'hp', 'attack', 'defense',
#        'sp_attack', 'sp_defense', 'speed', 'generation', 'legendary'],
#       dtype='object')

# %%
valores_nuevos = ['nombre','tipo1','tipo2','total','vida','ataque','defensa','ataque_sp','defensa_sp','velocidad','generación','legendario']
#pk_df.columns = pk_df.columns.str.replace(pk_df.columns,valores_nuevos)
pk_df.columns = pk_df.columns.str.replace('.','nombre')
"""
reemplaza la información de las columnas, como el valor del primer parámetro debe ser fijo, no efectuca cambio. Si
si colocamos el punto (.) como valor inicial no cambia nada ya que deben estar los nombres de las columnas y el segundo parámetro el valor a ser cambiado
"""
pk_df.columns
# Out:
# Index(['name', 'type1', 'type2', 'total', 'hp', 'attack', 'defense',
#        'sp_attack', 'sp_defense', 'speed', 'generation', 'legendary'],
#       dtype='object')

# %%
pk_df.sp_attack #el nombre de la columna es sp_attack, no sp_atk
# Out:
# number
# 1       65
# 2       80
# 3      100
# 3      122
# 3      100
#       ...
# 896     65
# 897    145
# 898     80
# 898     85
# 898    165
# Name: sp_attack, Length: 1072, dtype: int64

# %%
pk_df #Muestra el dataframe con las últimas modificaciones
# Out:
#                         name    type1   type2  total   hp  attack  defense  \
# number
# 1                  Bulbasaur    Grass  Poison    318   45      49       49
# 2                    Ivysaur    Grass  Poison    405   60      62       63
# 3                   Venusaur    Grass  Poison    525   80      82       83
# 3              Mega Venusaur    Grass  Poison    625   80     100      123
# 3        Gigantamax Venusaur    Grass  Poison    525   80      82       83
# ...                      ...      ...     ...    ...  ...     ...      ...
# 896                Glastrier      Ice     NaN    580  100     145      130
# 897                Spectrier    Ghost     NaN    580  100      65       60
# 898                  Calyrex  Psychic   Grass    500  100      80       80
# 898        Ice Rider Calyrex  Psychic     Ice    680  100     165      150
# 898     Shadow Rider Calyrex  Psychic   Ghost    680  100      85       80
#
#         sp_attack  sp_defense  speed  generation  legendary
# ...

# %%
help(pk_df.set_index) #Muestra un cuadro de dialogo

# %%
pk_df
'''
Si se especifica inplace=True, modifica el DataFrame original,
de lo contrario, crea un nuevo objeto
'''
pk_df.set_index('name',inplace=True) #me establece como index de la columna la palabra name

# %%
pk_df
# Out:
#                         type1   type2  total   hp  attack  defense  sp_attack  \
# name
# Bulbasaur               Grass  Poison    318   45      49       49         65
# Ivysaur                 Grass  Poison    405   60      62       63         80
# Venusaur                Grass  Poison    525   80      82       83        100
# Mega Venusaur           Grass  Poison    625   80     100      123        122
# Gigantamax Venusaur     Grass  Poison    525   80      82       83        100
# ...                       ...     ...    ...  ...     ...      ...        ...
# Glastrier                 Ice     NaN    580  100     145      130         65
# Spectrier               Ghost     NaN    580  100      65       60        145
# Calyrex               Psychic   Grass    500  100      80       80         80
# Ice Rider Calyrex     Psychic     Ice    680  100     165      150         85
# Shadow Rider Calyrex  Psychic   Ghost    680  100      85       80        165
#
# ...

# %%
pk_df.head(10) #Muestra primeros 10 registros
# Out:
#                      type1   type2  total  hp  attack  defense  sp_attack  \
# name
# Bulbasaur            Grass  Poison    318  45      49       49         65
# Ivysaur              Grass  Poison    405  60      62       63         80
# Venusaur             Grass  Poison    525  80      82       83        100
# Mega Venusaur        Grass  Poison    625  80     100      123        122
# Gigantamax Venusaur  Grass  Poison    525  80      82       83        100
# Charmander            Fire     NaN    309  39      52       43         60
# Charmeleon            Fire     NaN    405  58      64       58         80
# Charizard             Fire  Flying    534  78      84       78        109
# Mega Charizard X      Fire  Dragon    634  78     130      111        130
# Mega Charizard Y      Fire  Flying    634  78     104       78        159
#
#                      sp_defense  speed  generation  legendary
# name
# Bulbasaur                    65     45           1      False
# ...

# %%
pk_df.isna() #valida en todo el dataframe si los registros del datafram contienen el valor de NaN
# Out:
#                       type1  type2  total     hp  attack  defense  sp_attack  \
# name
# Bulbasaur             False  False  False  False   False    False      False
# Ivysaur               False  False  False  False   False    False      False
# Venusaur              False  False  False  False   False    False      False
# Mega Venusaur         False  False  False  False   False    False      False
# Gigantamax Venusaur   False  False  False  False   False    False      False
# ...                     ...    ...    ...    ...     ...      ...        ...
# Glastrier             False   True  False  False   False    False      False
# Spectrier             False   True  False  False   False    False      False
# Calyrex               False  False  False  False   False    False      False
# Ice Rider Calyrex     False  False  False  False   False    False      False
# Shadow Rider Calyrex  False  False  False  False   False    False      False
#
# ...

# %%
pk_df.isna().any() #sirve para validar si algun valor existe en el dataframe, coloca True si existe y false si no hay registros
# Out:
# type1         False
# type2          True
# total         False
# hp            False
# attack        False
# defense       False
# sp_attack     False
# sp_defense    False
# speed         False
# generation    False
# legendary     False
# dtype: bool

# %%
pk_df.isna().sum() #Sumeme todas las cantidades de los registros que tengan NaN, en el dataframe vemos que en la columna type2 hay 498 registros que contienen NaN
# Out:
# type1           0
# type2         498
# total           0
# hp              0
# attack          0
# defense         0
# sp_attack       0
# sp_defense      0
# speed           0
# generation      0
# legendary       0
# dtype: int64

# %%
'''
Eliminar registros con valores nulos
Axis 0: Eliminar los registors que tienen null
Axis 1: Elimina columnas que tengan registros null
'''
nuevo_elememento = pk_df.dropna(axis=0)
nuevo_elememento
# Out:
#                         type1   type2  total   hp  attack  defense  sp_attack  \
# name
# Bulbasaur               Grass  Poison    318   45      49       49         65
# Ivysaur                 Grass  Poison    405   60      62       63         80
# Venusaur                Grass  Poison    525   80      82       83        100
# Mega Venusaur           Grass  Poison    625   80     100      123        122
# Gigantamax Venusaur     Grass  Poison    525   80      82       83        100
# ...                       ...     ...    ...  ...     ...      ...        ...
# Zarude                   Dark   Grass    600  105     120      105         70
# Dada Zarude              Dark   Grass    600  105     120      105         70
# Calyrex               Psychic   Grass    500  100      80       80         80
# Ice Rider Calyrex     Psychic     Ice    680  100     165      150         85
# Shadow Rider Calyrex  Psychic   Ghost    680  100      85       80        165
#
# ...

# %%
pk_df
#nuevo_elememento #Este es el dataframe modificado con los elementos borrados que contengan valores null
# Out:
#                         type1   type2  total   hp  attack  defense  sp_attack  \
# name
# Bulbasaur               Grass  Poison    318   45      49       49         65
# Ivysaur                 Grass  Poison    405   60      62       63         80
# Venusaur                Grass  Poison    525   80      82       83        100
# Mega Venusaur           Grass  Poison    625   80     100      123        122
# Gigantamax Venusaur     Grass  Poison    525   80      82       83        100
# ...                       ...     ...    ...  ...     ...      ...        ...
# Glastrier                 Ice     NaN    580  100     145      130         65
# Spectrier               Ghost     NaN    580  100      65       60        145
# Calyrex               Psychic   Grass    500  100      80       80         80
# Ice Rider Calyrex     Psychic     Ice    680  100     165      150         85
# Shadow Rider Calyrex  Psychic   Ghost    680  100      85       80        165
#
# ...

# %%
'''
Reemplazar valores nulos, con algún valor estático
'''

pk_df.type2 = pk_df.type2.fillna('Sin dato') #Cambiamos el valor de empty a Sin dato para poder llenar los datos y que no queden vacios

# %%
pk_df.head(10) #Muestra primeros 10 registros
# Out:
#                      type1     type2  total  hp  attack  defense  sp_attack  \
# name
# Bulbasaur            Grass    Poison    318  45      49       49         65
# Ivysaur              Grass    Poison    405  60      62       63         80
# Venusaur             Grass    Poison    525  80      82       83        100
# Mega Venusaur        Grass    Poison    625  80     100      123        122
# Gigantamax Venusaur  Grass    Poison    525  80      82       83        100
# Charmander            Fire  Sin dato    309  39      52       43         60
# Charmeleon            Fire  Sin dato    405  58      64       58         80
# Charizard             Fire    Flying    534  78      84       78        109
# Mega Charizard X      Fire    Dragon    634  78     130      111        130
# Mega Charizard Y      Fire    Flying    634  78     104       78        159
#
#                      sp_defense  speed  generation  legendary
# name
# ...

# %%
pk_df.isna().sum() #Vemos que ya no hay valores nullos porque se han llenado esos valores nulos a 'Sin dato'
# Out:
# hello world    0
# type2          0
# type2          0
# total          0
# hp             0
# attack         0
# defense        0
# sp_attack      0
# sp_defense     0
# speed          0
# generation     0
# legendary      0
# dtype: int64

# %%
'''
Eliminando columnas de dataframe
'''

pk_df.drop('type2',axis=1,inplace=True)

# %%
pk_df
# Out:
#                         type1  total   hp  attack  defense  sp_attack  \
# name
# Bulbasaur               Grass    318   45      49       49         65
# Ivysaur                 Grass    405   60      62       63         80
# Venusaur                Grass    525   80      82       83        100
# Mega Venusaur           Grass    625   80     100      123        122
# Gigantamax Venusaur     Grass    525   80      82       83        100
# ...                       ...    ...  ...     ...      ...        ...
# Glastrier                 Ice    580  100     145      130         65
# Spectrier               Ghost    580  100      65       60        145
# Calyrex               Psychic    500  100      80       80         80
# Ice Rider Calyrex     Psychic    680  100     165      150         85
# Shadow Rider Calyrex  Psychic    680  100      85       80        165
#
#                       sp_defense  speed  generation  legendary
# name
# ...

# %%
pk_df.describe() #El método describe me calcula datos estádisticos, la destiación estándar, porcentajes, entre otros.
# Out:
#              total           hp       attack      defense    sp_attack  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean    440.885261    70.486940    80.938433    74.968284    73.273321
# std     121.379077    26.868039    32.463582    31.208059    32.643119
# min     175.000000     1.000000     5.000000     5.000000    10.000000
# 25%     330.000000    50.000000    56.000000    52.000000    50.000000
# 50%     460.500000    68.000000    80.000000    70.000000    65.000000
# 75%     519.250000    84.000000   100.000000    90.000000    95.000000
# max    1125.000000   255.000000   190.000000   250.000000   194.000000
#
#         sp_defense        speed   generation
# count  1072.000000  1072.000000  1072.000000
# mean     72.476679    68.792910     4.294776
# std      27.934253    30.076281     2.346472
# min      20.000000     5.000000     0.000000
# 25%      50.000000    45.000000     2.000000
# 50%      70.000000    65.000000     4.000000
# ...

# %%
#pk_df.type1.unique() #Teníamos la columna llamada type2 pero fue eliminada con el método dropna
pk_df.attack.unique()
"""
Usamos la columna attack para devolver una serie de los valores únicos que se encuentren en esa columna
"""
# Out:
# '\nUsamos la columna attack para devolver una serie de los valores únicos que se encuentren en esa columna\n'

# %%
pk_df.attack.value_counts()
"""
cambiamos de type2 ya que no tenemos esa columna, así que usamos la columna attack
para saber cuantos valores hay repetidos, por ejemeplo, vemos que un pokemon tiene un ataque de 100 y es un registro REPETIDO 53 veces
"""
# Out:
# '\ncambiamos de type1 ya que no tenemos esa columna, así que usamos la columna attack\npara saber cuantos valores hay repetidos, por ejemeplo, vemos que un pokemon tiene un ataque de 100 y es un registro REPETIDO 53 veces\n'

# %%
pk_df.attack.value_counts().keys()
"""
Nos devuelve una serie de los registros primarios, estos registros primarios son los datos no repetidos, pero si los más útilizados en la columna attack
"""
# Out:
# '\nNos devuelve una serie de los registros primarios, estos registros primarios son los datos no repetidos, pero si los más útilizados en la columna attack\n'

# %%
pk_df.attack.unique()

"""
Devuelve valores unicos de la columna attack
"""
# Out:
# '\nDevuelve valores unicos de la columna attack\n'

# %%
plt.figure(figsize=(15,10)) #usamos matploit para crear una figura y la función figure con el parámetro figsize para definir el tamaño de la figura, 15 y 10 es el tamaño en coordenadas
# No hay columnas attack, las cambie por attack y deffense
plt.bar(pk_df.attack.value_counts().keys(),pk_df.attack.value_counts()) #el valor attack en los pokemones lo colocamos aca para que nos muestre los valores indices y cuantas veces se repite
plt.show() #muestra el gráfico

# %%
pk_df.type1
# Out:
# name
# Bulbasaur                 Grass
# Ivysaur                   Grass
# Venusaur                  Grass
# Mega Venusaur             Grass
# Gigantamax Venusaur       Grass
#                          ...
# Glastrier                   Ice
# Spectrier                 Ghost
# Calyrex                 Psychic
# Ice Rider Calyrex       Psychic
# Shadow Rider Calyrex    Psychic
# Name: type1, Length: 1072, dtype: object

# %%
plt.figure(figsize=(5,5)) #Me crea una figura 5 por 5
sns.countplot(pk_df.type1.value_counts().keys()) #agarro los valores primarios del tipo de pokemon y los muestro
# Out:
# <Axes: xlabel='count', ylabel='type1'>

# %% [markdown]
# Cuando el gráfico se ve "apretado" o congestionado, es probable que sea debido a la falta de espacio para mostrar todas las etiquetas o elementos de forma clara. Esto puede suceder especialmente si tienes muchas categorías en el eje x, o si el tamaño de la figura es demasiado pequeño.

# %% [markdown]
# Aquí tienes algunas maneras de mejorar la visualización del gráfico para que sea más claro:

# %% [markdown]
# 1. Aumentar el Tamaño de la Figura
# Puedes intentar aumentar el tamaño de la figura para dar más espacio a los elementos del gráfico:

# %%
plt.figure(figsize=(15,6))  # Aumenta el tamaño de la figura
sns.countplot(x='type1', data=pk_df)
plt.xticks(rotation=50)  # Rota las etiquetas del eje x si es necesario
plt.show() # Muestra el gráfico

# %% [markdown]
# 2. Rotar Etiquetas del Eje X
# Si las etiquetas de las categorías están muy apretadas, rotarlas puede ayudar a que sean más legibles:

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='type1', data=pk_df)
plt.xticks(rotation=45)  # Rota las etiquetas del eje x
plt.show()

# %% [markdown]
# 3. Ajustar el Espaciado de las Etiquetas
# Ajustar el espaciado de las etiquetas también puede ayudar:

# %%
plt.figure(figsize=(10, 6)) #define el tamaño de la figura
sns.countplot(x='type1', data=pk_df) # el eje x corresponde a la columna del dataframe y el parámetro data de donde proviene el dataframe
plt.xticks(rotation=30) #al eje x le agregue una rotación de 30 grados
plt.tight_layout()  # Ajusta automáticamente el espaciado
plt.show() #Muestra el gráfico

# %% [markdown]
# 4. Reducir el Número de Categorías (si es aplicable)
# Si hay muchas categorías y el gráfico se vuelve ilegible, podrías considerar mostrar solo las más frecuentes o agrupar algunas categorías:

# %%
# Mostrar solo las categorías más frecuentes (por ejemplo, las 10 más comunes)
#top_types = pk_df['type1'].value_counts().nlargest(10).index
top_types = pk_df['type1'].value_counts().nlargest(10).index
#top_types
filtered_df = pk_df[pk_df['type1'].isin(top_types)]
#filtered_df
help(pd.Series.isin)
plt.figure(figsize=(10, 6))
sns.countplot(x='type1', data=filtered_df)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Help on function isin in module pandas.core.series:
#
# isin(self, values) -> 'Series'
#     Whether elements in Series are contained in `values`.
#
#     Return a boolean Series showing whether each element in the Series
#     matches an element in the passed sequence of `values` exactly.
#
#     Parameters
#     ----------
#     values : set or list-like
#         The sequence of values to test. Passing in a single string will
#         raise a ``TypeError``. Instead, turn a single string into a
#         list of one element.
#
#     Returns
#     -------
#     Series
#         Series of booleans indicating if each element is in values.
#
#     Raises
#     ------
#     TypeError
#       * If `values` is a string
#
#     See Also
#     --------
#     DataFrame.isin : Equivalent method on DataFrame.
#
#     Examples
#     --------
#     >>> s = pd.Series(['llama', 'cow', 'llama', 'beetle', 'llama',
#     ...                'hippo'], name='animal')
#     >>> s.isin(['cow', 'llama'])
# ...

# %% [markdown]
# 5. Añadir Espacios Adicionales
# Si las etiquetas son muy largas, puedes añadir espacio adicional a la figura para mejorar la legibilidad:

# %%
plt.figure(figsize=(15, 10))  # Aumenta el tamaño de la figura
sns.countplot(x='type1', data=pk_df) # el eje x corresponde a la columna del dataframe y el parámetro data de donde proviene el dataframe
plt.xticks(rotation=45) #agrega una rotación al eje x de los datos de 45 grados
plt.tight_layout(pad=1.0)  # Añade espacio adicional alrededor del gráfico
plt.show() # Muestra el dataframe

# %% [markdown]
# El método df.corr() en pandas se utiliza para calcular la matriz de correlación entre las columnas numéricas de un DataFrame. La correlación mide la relación entre dos variables y puede tomar valores entre -1 y 1:
#
# 1 indica una correlación positiva perfecta: cuando una variable aumenta, la otra también lo hace en la misma proporción.
# -1 indica una correlación negativa perfecta: cuando una variable aumenta, la otra disminuye en la misma proporción.
# 0 indica que no hay ninguna relación lineal entre las variables.

# %%
# Selecciona solo las columnas numéricas
numeric_df = pk_df.select_dtypes(include=['number', 'bool'])

# Calcula la matriz de correlación
correlation_matrix = numeric_df.corr()

# Crea el heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')

plt.xticks(rotation=10)#Agrega rotación al eje x
plt.yticks(rotation=20)#Agrega rotación al eje y
plt.tight_layout(pad=2.0) #hace una separación de las leyendas del layout

# Guarda la imagen
plt.savefig('heatmap.png')

# Muestra el heatmap
plt.show()
